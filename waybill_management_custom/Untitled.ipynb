# %%
# !tar chvfz notebook.tar.gz *
# Out:
# another_backup.tar.gz
# __init__.py
# __manifest__.py
# models/
# models/__init__.py
# models/__pycache__/
# models/__pycache__/__init__.cpython-310.pyc
# models/__pycache__/waybill.cpython-310.pyc
# models/waybill.py
# __pycache__/
# __pycache__/__init__.cpython-310.pyc
# security/
# security/ir.model.access.csv
# static/
# static/src/
# static/src/css/
# static/src/css/custom_background.css
# Untitled.ipynb
# views/
# views/fetch_waybills_wizard_views.xml
# views/waybill_action.xml
# views/waybill_menu.xml
# views/waybill_views.xml
# views/waybill_views_1.xml
# views/waybill_views_3.xml
# views/waybill_views_4.xml
# views/waybill_views_5.xml
# views/assets.xml
# wizards/
# wizards/__init__.py
# wizards/fetch_waybills_wizard.py
# wizards/fetch_waybills_wizard_1.py
# wizards/fetch_waybills_wizard_3.py
# wizards/fetch_waybills_wizard_4.py
# wizards/fetch_waybills_wizard_5.py
